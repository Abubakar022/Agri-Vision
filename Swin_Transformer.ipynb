# %%
# !nvidia-smi
# Out:
# Fri Oct 10 11:22:56 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip -q install timm torchmetrics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 55.0 MB/s eta 0:00:00

# %%
import os, time, math, json, random
import torch
from torch import nn
from torch.utils.data import DataLoader, Subset
from torchvision import datasets
from torch.optim import AdamW
from torch.optim.lr_scheduler import OneCycleLR
from torch.cuda.amp import autocast, GradScaler
from tqdm.auto import tqdm

import timm
from timm.data import resolve_data_config
from timm.data.transforms_factory import create_transform

SEED = 42
random.seed(SEED); torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Device:', device)
# Out:
# Device: cuda

# %%
# CHANGE THIS to your dataset folder
DATA_ROOT = '/content/unzipped_dataset' # This is the path where the zip file was extracted

assert os.path.exists(DATA_ROOT), f"Folder not found: {DATA_ROOT}"

# We’ll first scan classes without transforms, then create train/val transforms later.
dataset_for_classes = datasets.ImageFolder(DATA_ROOT)
classes = dataset_for_classes.classes
num_classes = len(classes)
print(f"Found {num_classes} classes:", classes)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipython-input-3796570061.py in <cell line: 0>()
#       2 DATA_ROOT = '/content/unzipped_dataset' # This is the path where the zip file was extracted
#       3
# ----> 4 assert os.path.exists(DATA_ROOT), f"Folder not found: {DATA_ROOT}"
#       5
#       6 # We’ll first scan classes without transforms, then create train/val transforms later.
#
# AssertionError: Folder not found: /content/unzipped_dataset
